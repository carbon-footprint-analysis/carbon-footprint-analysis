# %% [markdown]
# # Build Dataset Generation Config
#
# This notebook processes official energy data from:
#
# - EPE (Empresa de Pesquisa Energética)
# - ANEEL (Agência Nacional de Energia Elétrica)
#
# The goal is to generate the probabilistic configuration files used by the synthetic dataset generator.
#
# Outputs:
# - consumption_profiles.csv
# - energy_source_distribution.csv
# - company_size_distribution_by_usage.csv
# - usage_distribution_by_state.csv
# - seasonality_state_class_month.csv

# %% [markdown]
# Clona Projeto direto do github para facilitar

# %%
# !git clone https://github.com/carbon-footprint-analysis/carbon-footprint-analysis.git
# Out:
# Cloning into 'carbon-footprint-analysis'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 146 (delta 42), reused 129 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (146/146), 2.35 MiB | 10.41 MiB/s, done.
# Resolving deltas: 100% (42/42), done.

# %% [markdown]
# importa dados oficiais da empresa de pesquisa energetica e faz EDA + ETL para criar o dataset sintetico ainda !
#
# Abaixo e o data set de consumo por categoria e estado o consumo esta em MW mas abaixo sera convertido para kwh

# %%
import pandas as pd

epe = pd.read_csv('/content/carbon-footprint-analysis/data/raw/epe_industrial_consumption_by_state.csv',
                    encoding='latin-1',
                    sep=';',
                    decimal=',')

# %%
epe.head()
# Out:
#     Coluna1   DataExcel                  SetorIndustrial  UF        Regiao  \
# 0  20251201  01/12/2025  05 - EXTRAÇÃO DE CARVÃO MINERAL  AM         Norte
# 1  20251201  01/12/2025  05 - EXTRAÇÃO DE CARVÃO MINERAL  DF  Centro-Oeste
# 2  20251201  01/12/2025  05 - EXTRAÇÃO DE CARVÃO MINERAL  ES       Sudeste
# 3  20251201  01/12/2025  05 - EXTRAÇÃO DE CARVÃO MINERAL  MA      Nordeste
# 4  20251201  01/12/2025  05 - EXTRAÇÃO DE CARVÃO MINERAL  MG       Sudeste
#
#      Consumo  DataVersao
# 0     15.000  23/02/2026
# 1      1.077  23/02/2026
# 2     23.000  23/02/2026
# 3     39.586  23/02/2026
# 4  20994.000  23/02/2026

# %%
epe['DataExcel'] = pd.to_datetime(epe['DataExcel'], dayfirst=True)

# %%
epe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135676 entries, 0 to 135675
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Coluna1          135676 non-null  int64
#  1   DataExcel        135676 non-null  datetime64[ns]
#  2   SetorIndustrial  135676 non-null  object
#  3   UF               135676 non-null  object
#  4   Regiao           135676 non-null  object
#  5   Consumo          135676 non-null  float64
#  6   DataVersao       135676 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 7.2+ MB

# %%
epe['SetorIndustrial'].unique()
# Out:
# array(['05 - EXTRAÇÃO DE CARVÃO MINERAL',
#        '06 - EXTRAÇÃO DE PETRÓLEO E GÁS NATURAL',
#        '07 - EXTRAÇÃO DE MINERAIS METÁLICOS',
#        '08 - EXTRAÇÃO DE MINERAIS NÃO-METÁLICOS',
#        '09 - ATIVIDADES DE APOIO À EXTRAÇÃO DE MINERAIS',
#        '10 - FABRICAÇÃO DE PRODUTOS ALIMENTÍCIOS',
#        '11 - FABRICAÇÃO DE BEBIDAS',
#        '12 - FABRICAÇÃO DE PRODUTOS DO FUMO',
#        '13 - FABRICAÇÃO DE PRODUTOS TÊXTEIS',
#        '14 - CONFECÇÃO DE ARTIGOS DO VESTUÁRIO E ACESSÓRIOS',
#        '15 - PREPARAÇÃO DE COUROS E FABRICAÇÃO DE ARTEFATOS DE COURO, ARTIGOS PARA VIAGEM E CALÇADOS',
#        '16 - FABRICAÇÃO DE PRODUTOS DE MADEIRA',
#        '17 - FABRICAÇÃO DE CELULOSE, PAPEL E PRODUTOS DE PAPEL',
#        '18 - IMPRESSÃO E REPRODUÇÃO DE GRAVAÇÕES',
#        '19 - FABRICAÇÃO DE COQUE, DE PRODUTOS DERIVADOS DO PETRÓLEO E DE BIOCOMBUSTÍVEIS',
#        '20 - FABRICAÇÃO DE PRODUTOS QUÍMICOS',
#        '21 - FABRICAÇÃO DE PRODUTOS FARMOQUÍMICOS E FARMACÊUTICOS',
#        '22 - FABRICAÇÃO DE PRODUTOS DE BORRACHA E DE MATERIAL PLÁSTICO',
#        '23 - FABRICAÇÃO DE PRODUTOS DE MINERAIS NÃO-METÁLICOS',
#        '24 - METALURGIA',
#        '25 - FABRICAÇÃO DE PRODUTOS DE METAL, EXCETO MÁQUINAS E EQUIPAMENTOS',
#        '26 - FABRICAÇÃO DE EQUIPAMENTOS DE INFORMÁTICA, PRODUTOS ELETRÔNICOS E ÓPTICOS',
#        '27 - FABRICAÇÃO DE MÁQUINAS, APARELHOS E MATERIAIS ELÉTRICOS',
#        '28 - FABRICAÇÃO DE MÁQUINAS E EQUIPAMENTOS',
#        '29 - FABRICAÇÃO DE VEÍCULOS AUTOMOTORES, REBOQUES E CARROCERIAS',
#        '30 - FABRICAÇÃO DE OUTROS EQUIPAMENTOS DE TRANSPORTE, EXCETO VEÍCULOS AUTOMOTORES',
#        '31 - FABRICAÇÃO DE MÓVEIS',
#        '32 - FABRICAÇÃO DE PRODUTOS DIVERSOS',
#        '33 - MANUTENÇÃO, REPARAÇÃO E INSTALAÇÃO DE MÁQUINAS E EQUIPAMENTOS',
#        '35 - ELETRICIDADE, GÁS E OUTRAS UTILIDADES',
#        '36 - CAPTAÇÃO, TRATAMENTO E DISTRIBUIÇÃO DE ÁGUA',
#        '37 - ESGOTO E ATIVIDADES RELACIONADAS',
#        '38 - COLETA, TRATAMENTO E DISPOSIÇÃO DE RESÍDUOS; RECUPERAÇÃO DE MATERIAIS',
#        '39 - DESCONTAMINAÇÃO E OUTROS SERVIÇOS DE GESTÃO DE RESÍDUOS',
#        '41 - CONSTRUÇÃO DE EDIFÍCIOS', '42 - OBRAS DE INFRA-ESTRUTURA',
#        '43 - SERVIÇOS ESPECIALIZADOS PARA CONSTRUÇÃO'], dtype=object)

# %%
df = epe.copy()

# %%
df['year'] = df['DataExcel'].dt.year
df['month'] = df['DataExcel'].dt.month

# %%
df_2025 = df[df['year'] == 2025].copy()
df_2025.drop(columns=['DataVersao', 'DataExcel'], inplace=True)

# %%
df_2025.head(5)
# Out:
#     Coluna1                  SetorIndustrial  UF        Regiao    Consumo  \
# 0  20251201  05 - EXTRAÇÃO DE CARVÃO MINERAL  AM         Norte     15.000
# 1  20251201  05 - EXTRAÇÃO DE CARVÃO MINERAL  DF  Centro-Oeste      1.077
# 2  20251201  05 - EXTRAÇÃO DE CARVÃO MINERAL  ES       Sudeste     23.000
# 3  20251201  05 - EXTRAÇÃO DE CARVÃO MINERAL  MA      Nordeste     39.586
# 4  20251201  05 - EXTRAÇÃO DE CARVÃO MINERAL  MG       Sudeste  20994.000
#
#    year  month
# 0  2025     12
# 1  2025     12
# 2  2025     12
# 3  2025     12
# 4  2025     12

# %%
df_grouped = df.groupby('SetorIndustrial')['Consumo'].mean().reset_index()

# %%
df_grouped = df_grouped.rename(columns={'Consumo':'Consumo_MWh'})

# %%
df_grouped.head()
# Out:
#                                    SetorIndustrial   Consumo_MWh
# 0                  05 - EXTRAÇÃO DE CARVÃO MINERAL    658.978726
# 1          06 - EXTRAÇÃO DE PETRÓLEO E GÁS NATURAL   8514.621995
# 2              07 - EXTRAÇÃO DE MINERAIS METÁLICOS  43036.799370
# 3          08 - EXTRAÇÃO DE MINERAIS NÃO-METÁLICOS  11104.061692
# 4  09 - ATIVIDADES DE APOIO À EXTRAÇÃO DE MINERAIS    739.495885

# %%
df_grouped['Consumo_kWh'] = (df_grouped['Consumo_MWh']) * 1000

# %%
df_grouped.head()
# Out:
#                                    SetorIndustrial   Consumo_MWh   Consumo_kWh
# 0                  05 - EXTRAÇÃO DE CARVÃO MINERAL    658.978726  6.589787e+05
# 1          06 - EXTRAÇÃO DE PETRÓLEO E GÁS NATURAL   8514.621995  8.514622e+06
# 2              07 - EXTRAÇÃO DE MINERAIS METÁLICOS  43036.799370  4.303680e+07
# 3          08 - EXTRAÇÃO DE MINERAIS NÃO-METÁLICOS  11104.061692  1.110406e+07
# 4  09 - ATIVIDADES DE APOIO À EXTRAÇÃO DE MINERAIS    739.495885  7.394959e+05

# %%
df_grouped.to_csv('media_consumo_indutria_2025.csv')

# %% [markdown]
# Abertura do dados oficial consumo mensal por categoria a escala de energia esta em MW mas sera convertido em kwh.
#
# Tambem foi feito o EDA e ETL para criação do dataset sintetico !

# %%
import pandas as pd

epe_categoria = pd.read_csv('/content/carbon-footprint-analysis/data/raw/EPE - Dados_abertos_Consumo_Mensal.CSV',
                    encoding='latin-1',
                    sep=';',
                    decimal=',')

# %%
df_2025 = df[df['year'] == 2025].copy()
df_2025.drop(columns=['DataVersao', 'DataExcel'], inplace=True)

# %%
epe_categoria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59243 entries, 0 to 59242
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Data            59243 non-null  int64
#  1   DataExcel       59243 non-null  object
#  2   UF              59243 non-null  object
#  3   Regiao          59243 non-null  object
#  4   Sistema         59243 non-null  object
#  5   Classe          59243 non-null  object
#  6   TipoConsumidor  59243 non-null  object
#  7   Consumo         59243 non-null  object
#  8   Consumidores    59243 non-null  object
#  9   DataVersao      59243 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 4.5+ MB

# %%
epe_categoria['DataExcel'] = pd.to_datetime(epe_categoria['DataExcel'], dayfirst=True)

# %%
df = epe_categoria.copy()

# %%
df['year'] = df['DataExcel'].dt.year
df['month'] = df['DataExcel'].dt.month

# %%
df_2025 = df[df['year'] == 2025]

# %%
df_2025['Consumo'] = (
    df_2025['Consumo']
    .str.replace('.', '', regex=False)
    .str.replace(',', '.', regex=False)
    .astype(float)
)

df_2025['Consumidores'] = (
    df_2025['Consumidores']
    .astype(str)
    .str.replace('.', '', regex=False)
    .astype(float)
)
# Out:
# /tmp/ipykernel_14066/3063530973.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2025['Consumo'] = (
# /tmp/ipykernel_14066/3063530973.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2025['Consumidores'] = (

# %%
df_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3328 entries, 0 to 3327
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Data            3328 non-null   int64
#  1   DataExcel       3328 non-null   datetime64[ns]
#  2   UF              3328 non-null   object
#  3   Regiao          3328 non-null   object
#  4   Sistema         3328 non-null   object
#  5   Classe          3328 non-null   object
#  6   TipoConsumidor  3328 non-null   object
#  7   Consumo         3328 non-null   float64
#  8   Consumidores    3328 non-null   float64
#  9   DataVersao      3328 non-null   object
#  10  year            3328 non-null   int32
#  11  month           3328 non-null   int32
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(1), object(6)
# memory usage: 312.0+ KB

# %%
df_2025.head()
# Out:
#        Data  DataExcel  UF Regiao            Sistema       Classe  \
# 0  20251201 2025-12-01  AC  Norte  SISTEMAS ISOLADOS    Comercial
# 1  20251201 2025-12-01  AC  Norte  SISTEMAS ISOLADOS   Industrial
# 2  20251201 2025-12-01  AC  Norte  SISTEMAS ISOLADOS       Outros
# 3  20251201 2025-12-01  AC  Norte  SISTEMAS ISOLADOS  Residencial
# 4  20251201 2025-12-01  AC  Norte  SISTEMAS ISOLADOS        Rural
#
#   TipoConsumidor  Consumo  Consumidores  DataVersao  year  month
# 0         Cativo    175.7         478.0  23/02/2026  2025     12
# 1         Cativo      7.0           4.0  23/02/2026  2025     12
# 2         Cativo    495.1         382.0  23/02/2026  2025     12
# 3         Cativo   1266.8        8862.0  23/02/2026  2025     12
# 4         Cativo   1181.1         125.0  23/02/2026  2025     12

# %%
df_2025.drop(columns=['Data', 'DataVersao'], inplace=True)
# Out:
# /tmp/ipykernel_14066/3578452241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2025.drop(columns=['Data', 'DataVersao'], inplace=True)

# %%
df_2025 = df_2025.rename(columns={'Consumo':'Consumo_MWh'})

# %%
df_simplificado = (
    df_2025
    .groupby('Classe')
    .agg({
        'Consumo_MWh': 'sum',
        'Consumidores': 'sum'
    })
)

df_simplificado['consumo_medio_MWh'] = df_simplificado['Consumo_MWh'] / df_simplificado['Consumidores']

df_simplificado = df_simplificado.sort_values('Consumo_MWh', ascending=False)

# %%
df_simplificado['Consumo_kWh'] = (df_simplificado['Consumo_MWh']) * 1000
df_simplificado['consumo_medio_KWh'] = (df_simplificado['consumo_medio_MWh']) * 1000

# %%
df_simplificado = df_simplificado[[
    'Consumidores',
    'Consumo_MWh',
    'Consumo_kWh',
    'consumo_medio_MWh',
    'consumo_medio_KWh'
]]

# %%
df_simplificado
# Out:
#              Consumidores  Consumo_MWh   Consumo_kWh  consumo_medio_MWh  \
# Classe
# Industrial   5.408760e+06  198858357.9  1.988584e+11          36.765979
# Residencial  1.004322e+09  179155039.1  1.791550e+11           0.178384
# Comercial    7.399134e+07  102288641.3  1.022886e+11           1.382441
# Outros       1.059433e+07   51581431.9  5.158143e+10           4.868779
# Rural        4.604696e+07   30907605.1  3.090761e+10           0.671219
#
#              consumo_medio_KWh
# Classe
# Industrial        36765.979245
# Residencial         178.384142
# Comercial          1382.440719
# Outros             4868.778995
# Rural               671.219246

# %%
df_simplificado.to_csv('consumo_medio_categoria_2025.csv')

# %% [markdown]
# Verificando a sanidade dos dados

# %%
df_grouped.head()
# Out:
#                                    SetorIndustrial   Consumo_MWh   Consumo_kWh
# 0                  05 - EXTRAÇÃO DE CARVÃO MINERAL    658.978726  6.589787e+05
# 1          06 - EXTRAÇÃO DE PETRÓLEO E GÁS NATURAL   8514.621995  8.514622e+06
# 2              07 - EXTRAÇÃO DE MINERAIS METÁLICOS  43036.799370  4.303680e+07
# 3          08 - EXTRAÇÃO DE MINERAIS NÃO-METÁLICOS  11104.061692  1.110406e+07
# 4  09 - ATIVIDADES DE APOIO À EXTRAÇÃO DE MINERAIS    739.495885  7.394959e+05

# %%
df_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SetorIndustrial  37 non-null     object
#  1   Consumo_MWh      37 non-null     float64
#  2   Consumo_kWh      37 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1020.0+ bytes

# %%
df_simplificado.head()
# Out:
#              Consumidores  Consumo_MWh   Consumo_kWh  consumo_medio_MWh  \
# Classe
# Industrial   5.408760e+06  198858357.9  1.988584e+11          36.765979
# Residencial  1.004322e+09  179155039.1  1.791550e+11           0.178384
# Comercial    7.399134e+07  102288641.3  1.022886e+11           1.382441
# Outros       1.059433e+07   51581431.9  5.158143e+10           4.868779
# Rural        4.604696e+07   30907605.1  3.090761e+10           0.671219
#
#              consumo_medio_KWh
# Classe
# Industrial        36765.979245
# Residencial         178.384142
# Comercial          1382.440719
# Outros             4868.778995
# Rural               671.219246

# %%
df_simplificado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Industrial to Rural
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Consumidores       5 non-null      float64
#  1   Consumo_MWh        5 non-null      float64
#  2   Consumo_kWh        5 non-null      float64
#  3   consumo_medio_MWh  5 non-null      float64
#  4   consumo_medio_KWh  5 non-null      float64
# dtypes: float64(5)
# memory usage: 240.0+ bytes

# %% [markdown]
# Criação do consumption_profile.csv

# %%
df_profiles = df_simplificado.copy()

# %%
df_profiles.head()
# Out:
#              Consumidores  Consumo_MWh   Consumo_kWh  consumo_medio_MWh  \
# Classe
# Industrial   5.408760e+06  198858357.9  1.988584e+11          36.765979
# Residencial  1.004322e+09  179155039.1  1.791550e+11           0.178384
# Comercial    7.399134e+07  102288641.3  1.022886e+11           1.382441
# Outros       1.059433e+07   51581431.9  5.158143e+10           4.868779
# Rural        4.604696e+07   30907605.1  3.090761e+10           0.671219
#
#              consumo_medio_KWh
# Classe
# Industrial        36765.979245
# Residencial         178.384142
# Comercial          1382.440719
# Outros             4868.778995
# Rural               671.219246

# %%
def get_sigma(classe):
    if classe == 'Industrial':
        return 0.6
    elif classe == 'Comercial':
        return 0.4
    elif classe == 'Residencial':
        return 0.3
    else:
        return 0.35

df_profiles['sigma'] = df_profiles.index.map(get_sigma)

# %%
map_usage = {
    'Industrial': 'industrial',
    'Comercial': 'commercial',
    'Residencial': 'residential',
    'Rural': 'agriculture',
    'Outros': 'other'
}

df_profiles['usage_type'] = df_profiles.index.map(map_usage)

# %%
import numpy as np

df_profiles['mu'] = np.log(df_profiles['consumo_medio_KWh'])

# %%
df_final = df_profiles.copy()
df_final['fuel_type'] = 'electric'
df_final['distribution_type'] = 'lognormal'
df_final['param_1'] = df_profiles['mu']
df_final['param_2'] = df_profiles['sigma']
df_final['param_1_name'] = 'mu'
df_final['param_2_name'] = 'sigma'
df_final['unit'] = 'kWh'
df_final['is_energy_based'] = True

# %%
df_final.head()
# Out:
#              Consumidores  Consumo_MWh   Consumo_kWh  consumo_medio_MWh  \
# Classe
# Industrial   5.408760e+06  198858357.9  1.988584e+11          36.765979
# Residencial  1.004322e+09  179155039.1  1.791550e+11           0.178384
# Comercial    7.399134e+07  102288641.3  1.022886e+11           1.382441
# Outros       1.059433e+07   51581431.9  5.158143e+10           4.868779
# Rural        4.604696e+07   30907605.1  3.090761e+10           0.671219
#
#              consumo_medio_KWh  sigma   usage_type         mu fuel_type  \
# Classe
# Industrial        36765.979245   0.60   industrial  10.512328  electric
# Residencial         178.384142   0.30  residential   5.183939  electric
# Comercial          1382.440719   0.40   commercial   7.231606  electric
# Outros             4868.778995   0.35        other   8.490598  electric
# Rural               671.219246   0.35  agriculture   6.509096  electric
#
#             distribution_type    param_1  param_2 param_1_name param_2_name  \
# Classe
# Industrial          lognormal  10.512328     0.60           mu        sigma
# Residencial         lognormal   5.183939     0.30           mu        sigma
# Comercial           lognormal   7.231606     0.40           mu        sigma
# Outros              lognormal   8.490598     0.35           mu        sigma
# Rural               lognormal   6.509096     0.35           mu        sigma
#
#             unit  is_energy_based
# Classe
# Industrial   kWh             True
# Residencial  kWh             True
# Comercial    kWh             True
# Outros       kWh             True
# Rural        kWh             True

# %%
df_export = df_final[[
    'usage_type',
    'fuel_type',
    'distribution_type',
    'param_1',
    'param_2',
    'param_1_name',
    'param_2_name',
    'unit',
    'is_energy_based'
]].copy()

# %%
df_export.head()
# Out:
#               usage_type fuel_type distribution_type    param_1  param_2  \
# Classe
# Industrial    industrial  electric         lognormal  10.512328     0.60
# Residencial  residential  electric         lognormal   5.183939     0.30
# Comercial     commercial  electric         lognormal   7.231606     0.40
# Outros             other  electric         lognormal   8.490598     0.35
# Rural        agriculture  electric         lognormal   6.509096     0.35
#
#             param_1_name param_2_name unit  is_energy_based
# Classe
# Industrial            mu        sigma  kWh             True
# Residencial           mu        sigma  kWh             True
# Comercial             mu        sigma  kWh             True
# Outros                mu        sigma  kWh             True
# Rural                 mu        sigma  kWh             True

# %%
df_export.to_csv('v2_consumption_profiles.csv', index=False)

# %% [markdown]
# transformar config em dados sinteticos reais

# %% [markdown]
# carergando profile

# %%
import pandas as pd
import numpy as np

profiles = pd.read_csv('/content/v2_consumption_profiles.csv')

# %% [markdown]
# gerar função

# %%
def generate_consumption(profile_row):

    if profile_row['distribution_type'] == 'lognormal':
        mu = profile_row['param_1']
        sigma = profile_row['param_2']

        value = np.random.lognormal(mu, sigma)

        # LIMITADOR
        max_value = 10 * np.exp(mu)
        value = min(value, max_value)

        return value

    else:
        raise ValueError("Distribuição não suportada")

# %% [markdown]
# gerar evento

# %%
usage_probs = {
    'residential': 0.6,
    'commercial': 0.2,
    'industrial': 0.1,
    'agriculture': 0.05,
    'other': 0.05
}

# %%
def generate_event(profiles):

    weights = profiles['usage_type'].map(usage_probs)

    row = profiles.sample(1, weights=weights).iloc[0]

    consumption = generate_consumption(row)

    return {
        'usage_type': row['usage_type'],
        'fuel_type': row['fuel_type'],
        'energy_kwh': consumption
    }

# %% [markdown]
# gerar dataset

# %%
def generate_dataset(n, profiles):
    data = []

    for _ in range(n):
        event = generate_event(profiles)
        data.append(event)

    return pd.DataFrame(data)

# %% [markdown]
# test

# %%
df = generate_dataset(10000, profiles)

# %%
df.head()
# Out:
#     usage_type fuel_type   energy_kwh
# 0  residential  electric   145.812338
# 1  residential  electric   158.333162
# 2   commercial  electric  1001.553934
# 3   commercial  electric  1037.048933
# 4  residential  electric    96.501452

# %%
df.to_csv('df_gerado_teste.csv')

# %%
df['usage_type'].value_counts(normalize=True)
# Out:
# usage_type
# residential    0.5978
# commercial     0.1991
# industrial     0.1035
# other          0.0499
# agriculture    0.0497
# Name: proportion, dtype: float64

# %%
df.groupby('usage_type')['energy_kwh'].describe()
# Out:
#               count          mean           std          min           25%  \
# usage_type
# agriculture   497.0    711.894767    261.257160   217.150013    524.773970
# commercial   1991.0   1492.614437    623.311844   380.116116   1040.972291
# industrial   1035.0  44714.594752  31289.917908  4920.047757  24783.258856
# other         499.0   5134.445525   1901.085582  1763.123615   3791.135939
# residential  5978.0    187.235395     57.745016    62.986973    146.272583
#
#                       50%           75%            max
# usage_type
# agriculture    659.700283    843.100128    2078.104356
# commercial    1376.059974   1820.256271    4841.538741
# industrial   37058.338143  54482.117451  267212.836404
# other         4825.934941   6144.772430   13088.206168
# residential    177.786494    219.732071     541.646381

# %%
df['energy_kwh'].max()
# Out:
# 267212.8364039786

# %%
(df['energy_kwh'] < 0).sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt

df[df['usage_type']=='industrial']['energy_kwh'].hist(bins=50)
plt.title('Industrial')
plt.show()

# %% [markdown]
# criando o energy _source_distribution.csv

# %%
df_aneel = pd.read_csv('/content/carbon-footprint-analysis/data/raw/aneel_generation.csv',
                       encoding='latin-1',
                       sep=';',
                       decimal=',')

# %%
df_aneel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495 entries, 0 to 494
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   DatGeracaoConjuntoDados  495 non-null    object
#  1   SigTipoGeracao           495 non-null    object
#  2   QtdUsinasPeriodo         495 non-null    int64
#  3   MdaPotenciaInstaladaKW   495 non-null    float64
#  4   MesReferencia            495 non-null    int64
#  5   AnoReferencia            495 non-null    int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 23.3+ KB

# %%
df_aneel.head()
# Out:
#   DatGeracaoConjuntoDados SigTipoGeracao  QtdUsinasPeriodo  \
# 0              2026-03-01            CGH                 0
# 1              2026-03-01            EOL                 7
# 2              2026-03-01            PCH               303
# 3              2026-03-01            UFV                 0
# 4              2026-03-01            UHE               133
#
#    MdaPotenciaInstaladaKW  MesReferencia  AnoReferencia
# 0                     0.0             12           2001
# 1                 21000.0             12           2001
# 2                855000.0             12           2001
# 3                     0.0             12           2001
# 4              61554000.0             12           2001

# %%
df_aneel['AnoReferencia'].unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023, 2024, 2025])

# %%
df_aneel = df_aneel[df_aneel['AnoReferencia']==2025]

# %%
df_aneel['SigTipoGeracao'].unique()
# Out:
# array(['EOL', 'CGH', 'UFV', 'PCH', 'UHE', 'UTE', 'UTN'], dtype=object)

# %%
df_grouped = df_aneel.groupby('SigTipoGeracao')['MdaPotenciaInstaladaKW'].sum()

# %%
df_grouped.head()
# Out:
# SigTipoGeracao
# CGH    3.577829e+06
# EOL    1.360294e+08
# PCH    2.382840e+07
# UFV    7.451254e+07
# UHE    4.128522e+08
# Name: MdaPotenciaInstaladaKW, dtype: float64

# %% [markdown]
# converter para probabilidade

# %%
df_dist = df_grouped / df_grouped.sum()

# %% [markdown]
# transformar e dataframe

# %%
df_dist.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 7 entries, CGH to UTN
# Series name: MdaPotenciaInstaladaKW
# Non-Null Count  Dtype
# --------------  -----
# 7 non-null      float64
# dtypes: float64(1)
# memory usage: 112.0+ bytes

# %%
df_grouped = df_aneel.groupby('SigTipoGeracao')['MdaPotenciaInstaladaKW'].sum().reset_index()

df_grouped.columns = ['energy_source', 'total_generation']

# %%
df_grouped['probability'] = df_grouped['total_generation'] / df_grouped['total_generation'].sum()

df_dist = df_grouped[['energy_source', 'probability']]
df_dist = df_dist.copy()

# %%
df_dist.head()
# Out:
#   energy_source  probability
# 0           CGH     0.004194
# 1           EOL     0.159455
# 2           PCH     0.027932
# 3           UFV     0.087344
# 4           UHE     0.483948

# %%
df_dist['probability'].sum()
# Out:
# np.float64(1.0)

# %%
map_sources = {
    'UHE': 'hydro',      # Hidrelétrica grande
    'PCH': 'hydro',      # Pequena central hidrelétrica
    'CGH': 'hydro',      # Central geradora hidráulica

    'EOL': 'wind',       # Eólica

    'UFV': 'solar',      # Solar fotovoltaica

    # se aparecer depois:
    'UTE': 'thermal',    # termoelétrica (genérico)
    'UTN': 'nuclear',    # nuclear
}
df_dist['energy_source'] = df_dist['energy_source'].map(map_sources)

# %%
df_dist = df_dist.groupby('energy_source')['probability'].sum().reset_index()

# %%
df_dist['probability'] = df_dist['probability'] / df_dist['probability'].sum()

# %%
df_dist = df_dist.sort_values('probability', ascending=False)

# %%
df_dist
# Out:
#   energy_source  probability
# 0         hydro     0.516074
# 3       thermal     0.227796
# 4          wind     0.159455
# 2         solar     0.087344
# 1       nuclear     0.009331

# %%
df_dist.to_csv('energy _source_distribution.csv')

# %% [markdown]
# Inserir a emissão co2

# %%
emission_factors = pd.read_csv('/content/carbon-footprint-analysis/data/external/v2_energy_source_emission_factors.csv')

# %%
def calculate_emission(energy_kwh, energy_source, emission_df):

    row = emission_df.loc[
        emission_df['energy_source'] == energy_source
    ]

    if row.empty:
        raise ValueError(f"Fonte não encontrada: {energy_source}")

    factor = row['emission_factor'].values[0]

    return energy_kwh * factor

# %%
def sample_energy_source(dist_df):
    return dist_df.sample(1, weights=dist_df['probability']).iloc[0]['energy_source']

# %%
def normalize_usage_types(series):

    mapping = {
        'residencial': 'residential',
        'rural': 'agriculture',
        'outros': 'other',
        'industrial': 'industrial',
        'commercial': 'commercial'
    }

    return (
        series
        .str.strip()
        .str.lower()
        .replace(mapping)
    )

# %%
def generate_event(profiles, energy_dist, emission_df):

    usage_types = normalize_usage_types(profiles['usage_type'])

    weights = usage_types.map(usage_probs)

    if weights.sum() == 0:
        raise ValueError("usage_probs não corresponde aos usage_type do profile")

    row = profiles.sample(1, weights=weights).iloc[0]

    consumption = generate_consumption(row)

    energy_source = sample_energy_source(energy_dist)

    co2 = calculate_emission(consumption, energy_source, emission_df)

    return {
        'usage_type': row['usage_type'],
        'fuel_type': row['fuel_type'],
        'energy_kwh': consumption,
        'energy_source': energy_source,
        'co2_emission': co2
    }

# %%
import pandas as pd
profiles = pd.read_csv('/content/carbon-footprint-analysis/data/external/v2_consumption_profiles.csv')

energy_dist = pd.read_csv('/content/carbon-footprint-analysis/data/external/v2_energy _source_distribution.csv')

emission_df = pd.read_csv('/content/carbon-footprint-analysis/data/external/v2_energy_source_emission_factors.csv')

# %%
event = generate_event(profiles, energy_dist, emission_df)
event
# Out:
# {'usage_type': 'Residencial',
#  'fuel_type': 'eletrico',
#  'energy_kwh': 169.96312779551727,
#  'energy_source': 'hydro',
#  'co2_emission': np.float64(3.3992625559103455)}

# %%
def generate_dataset(n, profiles, energy_dist, emission_df):
    data = []

    for _ in range(n):
        event = generate_event(profiles, energy_dist, emission_df)
        data.append(event)

    return pd.DataFrame(data)

# %%
df = generate_dataset(10000, profiles, energy_dist, emission_df)
df.describe()
# Out:
#           energy_kwh   co2_emission
# count   10000.000000   10000.000000
# mean     6154.569595     916.994562
# std     17925.836715    5305.485053
# min        58.852958       0.736652
# 25%       157.311876       3.027489
# 50%       203.118346       4.689847
# 75%       416.817869     107.724147
# max    252050.175866  108024.037343

# %%
df.head()
# Out:
#     usage_type fuel_type  energy_kwh energy_source  co2_emission
# 0  Residencial  eletrico  170.447338       thermal    102.268403
# 1        Rural  eletrico  477.796740         hydro      9.555935
# 2  Residencial  eletrico  232.292480         hydro      4.645850
# 3  Residencial  eletrico   97.316307       thermal     58.389784
# 4  Residencial  eletrico  192.969051         hydro      3.859381

# %% [markdown]
# Adicionando ID e datas

# %%
company_id = f"C{np.random.randint(1000,9999)}"

# %%
date = pd.Timestamp('2025-01-01') + pd.to_timedelta(np.random.randint(0, 365), unit='D')

# %%
states = [
'SP','MG','RJ','BA','PR','RS','SC','GO','PE','CE',
'PA','MT','ES','DF','MS','MA','RN','PB','AL','PI',
'RO','SE','TO','AC','AP','RR','AM'
]

state_weights = [
0.22,0.10,0.09,0.07,0.06,0.06,0.04,0.04,0.04,0.04,
0.03,0.03,0.02,0.02,0.02,0.02,0.015,0.015,0.01,0.01,
0.008,0.008,0.006,0.005,0.005,0.003,0.02
]

# %%
len(states), len(state_weights)
# Out:
# (27, 27)

# %%
state_weights = np.array(state_weights)
state_weights = state_weights / state_weights.sum()
state_weights
# Out:
# array([0.21890547, 0.09950249, 0.08955224, 0.06965174, 0.05970149,
#        0.05970149, 0.039801  , 0.039801  , 0.039801  , 0.039801  ,
#        0.02985075, 0.02985075, 0.0199005 , 0.0199005 , 0.0199005 ,
#        0.0199005 , 0.01492537, 0.01492537, 0.00995025, 0.00995025,
#        0.0079602 , 0.0079602 , 0.00597015, 0.00497512, 0.00497512,
#        0.00298507, 0.0199005 ])

# %%
def generate_event(profiles, energy_dist, emission_df):

    usage_types = normalize_usage_types(profiles['usage_type'])

    weights = usage_types.map(usage_probs)

    if weights.sum() == 0:
        raise ValueError("usage_probs não corresponde aos usage_type do profile")

    row = profiles.sample(1, weights=weights).iloc[0]

    consumption = generate_consumption(row)

    energy_source = sample_energy_source(energy_dist)

    co2 = calculate_emission(consumption, energy_source, emission_df)

    return {
        'company_id': f"C{np.random.randint(100000,999999)}",
        'date': pd.Timestamp('2025-01-01') + pd.to_timedelta(np.random.randint(0,365), unit='D'),
        'state': np.random.choice(states, p=state_weights),
        'usage_type': row['usage_type'],
        'fuel_type': row['fuel_type'],
        'energy_kwh': consumption,
        'energy_source': energy_source,
        'co2_emission': co2
    }

# %%
def generate_dataset(n, profiles, energy_dist, emission_df):
    data = []

    for _ in range(n):
        event = generate_event(profiles, energy_dist, emission_df)
        data.append(event)

    return pd.DataFrame(data)

# %%
df = generate_dataset(10000, profiles, energy_dist, emission_df)
df.describe()
# Out:
#                              date     energy_kwh  co2_emission
# count                       10000   10000.000000  10000.000000
# mean   2025-07-02 08:34:39.360000    5865.613311    867.664037
# min           2025-01-01 00:00:00      60.697928      0.661955
# 25%           2025-04-02 00:00:00     157.522265      3.030423
# 50%           2025-07-02 12:00:00     203.234227      4.698370
# 75%           2025-10-02 00:00:00     393.093142    105.673777
# max           2025-12-31 00:00:00  275527.974860  84846.398438
# std                           NaN   17346.957653   4866.876536

# %%
df
# Out:
#      company_id       date state   usage_type fuel_type    energy_kwh  \
# 0       C905841 2025-03-19    MS  Residencial  eletrico    140.751709
# 1       C436213 2025-12-12    RS  Residencial  eletrico    140.855965
# 2       C796286 2025-03-14    PA  Residencial  eletrico    230.487628
# 3       C161549 2025-02-01    PA  Residencial  eletrico    138.362906
# 4       C770617 2025-03-12    BA        Rural  eletrico    496.667459
# ...         ...        ...   ...          ...       ...           ...
# 9995    C350052 2025-09-24    BA  Residencial  eletrico    303.305498
# 9996    C847287 2025-01-02    MG   Industrial  eletrico  61182.307317
# 9997    C723570 2025-09-01    GO  Residencial  eletrico    164.599564
# 9998    C310916 2025-08-09    SC  Residencial  eletrico    219.453458
# 9999    C706384 2025-11-07    PR  Residencial  eletrico    103.350040
#
#      energy_source  co2_emission
# 0            hydro      2.815034
# 1            hydro      2.817119
# 2            hydro      4.609753
# 3          thermal     83.017744
# 4            hydro      9.933349
# ...            ...           ...
# 9995       nuclear      3.033055
# 9996         hydro   1223.646146
# 9997         hydro      3.291991
# 9998         hydro      4.389069
# 9999         hydro      2.067001
#
# [10000 rows x 8 columns]

# %% [markdown]
# Adicionando regras mais realistas, do jeito que esta esta pode criar industria pesadas na msm probabilidade entre ACRE e São Paulo

# %%
df_epe = pd.read_csv('/content/carbon-footprint-analysis/data/raw/EPE - Dados_abertos_Consumo_Mensal.CSV',
                    encoding='latin-1',
                    sep=';',
                    decimal=',')

# %%
df_epe.columns
# Out:
# Index(['Data', 'DataExcel', 'UF', 'Regiao', 'Sistema', 'Classe',
#        'TipoConsumidor', 'Consumo', 'Consumidores', 'DataVersao'],
#       dtype='object')

# %%
df_epe.head(5)
# Out:
#        Data   DataExcel  UF Regiao            Sistema       Classe  \
# 0  20251201  01/12/2025  AC  Norte  SISTEMAS ISOLADOS    Comercial
# 1  20251201  01/12/2025  AC  Norte  SISTEMAS ISOLADOS   Industrial
# 2  20251201  01/12/2025  AC  Norte  SISTEMAS ISOLADOS       Outros
# 3  20251201  01/12/2025  AC  Norte  SISTEMAS ISOLADOS  Residencial
# 4  20251201  01/12/2025  AC  Norte  SISTEMAS ISOLADOS        Rural
#
#   TipoConsumidor  Consumo Consumidores  DataVersao
# 0         Cativo    175,7          478  23/02/2026
# 1         Cativo      7,0            4  23/02/2026
# 2         Cativo    495,1          382  23/02/2026
# 3         Cativo  1.266,8        8.862  23/02/2026
# 4         Cativo  1.181,1          125  23/02/2026

# %%
df_epe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59243 entries, 0 to 59242
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Data            59243 non-null  int64
#  1   DataExcel       59243 non-null  object
#  2   UF              59243 non-null  object
#  3   Regiao          59243 non-null  object
#  4   Sistema         59243 non-null  object
#  5   Classe          59243 non-null  object
#  6   TipoConsumidor  59243 non-null  object
#  7   Consumo         59243 non-null  object
#  8   Consumidores    59243 non-null  object
#  9   DataVersao      59243 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 4.5+ MB

# %%
df_epe['Consumo'] = (
    df_epe['Consumo']
    .str.replace('.', '', regex=False)
    .str.replace(',', '.', regex=False)
    .astype(float)
)

# %%
df_sector_state = (
    df_epe
    .groupby(['UF','Classe'])['Consumo']
    .sum()
    .reset_index()
)

# %%
df_sector_state.head(20)
# Out:
#     UF       Classe     Consumo
# 0   AC    Comercial   4437987.7
# 1   AC   Industrial    841467.5
# 2   AC       Outros   4101501.8
# 3   AC  Residencial   9096890.3
# 4   AC        Rural    964581.4
# 5   AL    Comercial  14975797.6
# 6   AL   Industrial  37928026.3
# 7   AL       Outros  13214271.0
# 8   AL  Residencial  27863262.6
# 9   AL        Rural   3855553.4
# 10  AM    Comercial  25803225.1
# 11  AM   Industrial  37993902.5
# 12  AM       Outros  19942473.5
# 13  AM  Residencial  39488584.6
# 14  AM        Rural   1322763.5
# 15  AP    Comercial   4862019.5
# 16  AP   Industrial   1232802.7
# 17  AP       Outros   3748929.4
# 18  AP  Residencial  10905245.1
# 19  AP        Rural     85293.0

# %%
df_sector_state['probability'] = (
    df_sector_state
    .groupby('UF')['Consumo']
    .transform(lambda x: x / x.sum())
)

# %%
usage_distribution_by_state = df_sector_state.pivot(
    index='UF',
    columns='Classe',
    values='probability'
)

# %%
usage_distribution_by_state.to_csv('usage_distribution_by_state.csv')

# %%
states = [
'SP','MG','RJ','BA','PR','RS','SC','GO','PE','CE',
'PA','MT','ES','DF','MS','MA','RN','PB','AL','PI',
'RO','SE','TO','AC','AP','RR','AM'
]

state_weights = [
0.22,0.10,0.09,0.07,0.06,0.06,0.04,0.04,0.04,0.04,
0.03,0.03,0.02,0.02,0.02,0.02,0.015,0.015,0.01,0.01,
0.008,0.008,0.006,0.005,0.005,0.003,0.02
]

state_weights = np.array(state_weights)
state_weights = state_weights / state_weights.sum()

# %%
def generate_event(profiles, energy_dist, emission_df):

    # sorteia estado
    state = np.random.choice(states, p=state_weights)

    # pega probabilidades de setor para esse estado
    usage_probs_state = usage_distribution_by_state.loc[state].values
    usage_probs_state = usage_probs_state / usage_probs_state.sum()

    # sorteia setor
    usage_types = profiles['usage_type'].unique()

    usage_type = np.random.choice(
        usage_types,
        p=usage_probs_state
    )

    # filtra profiles para esse setor
    profiles_subset = profiles[profiles['usage_type'] == usage_type]

    # escolhe linha de profile
    row = profiles_subset.sample(1).iloc[0]

    # gera consumo
    consumption = generate_consumption(row)

    # sorteia fonte de energia
    energy_source = sample_energy_source(energy_dist)

    # calcula CO2
    co2 = calculate_emission(consumption, energy_source, emission_df)

    return {
        'company_id': f"C{np.random.randint(100000,999999)}",
        'date': pd.Timestamp('2025-01-01') + pd.to_timedelta(np.random.randint(0,365), unit='D'),
        'state': np.random.choice(states, p=state_weights),
        'usage_type': usage_type,
        'fuel_type': row['fuel_type'],
        'energy_kwh': consumption,
        'energy_source': energy_source,
        'co2_emission': co2
    }

# %%
def generate_dataset(n, profiles, energy_dist, emission_df):
    data = []

    for _ in range(n):
        event = generate_event(profiles, energy_dist, emission_df)
        data.append(event)

    return pd.DataFrame(data)

# %%
df = generate_dataset(10000, profiles, energy_dist, emission_df)
df.describe()
# Out:
#                              date     energy_kwh   co2_emission
# count                       10000   10000.000000   10000.000000
# mean   2025-06-30 08:11:28.320000    9665.321100    1440.609467
# min           2025-01-01 00:00:00      57.451690       0.667373
# 25%           2025-04-01 00:00:00     202.146913       4.751488
# 50%           2025-06-29 00:00:00    1871.124021      75.440850
# 75%           2025-09-29 00:00:00    6242.289330     372.799498
# max           2025-12-31 00:00:00  264171.118644  110371.025950
# std                           NaN   20033.931487    6097.940292

# %%
df
# Out:
#      company_id       date state   usage_type fuel_type     energy_kwh  \
# 0       C446120 2025-07-17    RS  Residencial  eletrico     178.133826
# 1       C977441 2025-02-03    AM       Outros  eletrico    6077.688797
# 2       C813580 2025-06-05    BA  Residencial  eletrico     202.707631
# 3       C167031 2025-08-14    SP  Residencial  eletrico     197.621039
# 4       C811353 2025-05-11    SC  Residencial  eletrico     202.042663
# ...         ...        ...   ...          ...       ...            ...
# 9995    C159929 2025-12-10    TO       Outros  eletrico    4501.030460
# 9996    C408533 2025-07-10    PR  Residencial  eletrico     278.411250
# 9997    C586364 2025-04-21    BA   Industrial  eletrico  153921.374890
# 9998    C550919 2025-08-07    SC  Residencial  eletrico     236.471360
# 9999    C735167 2025-05-06    SP  Residencial  eletrico     155.237543
#
#      energy_source  co2_emission
# 0             wind      1.781338
# 1            hydro    121.553776
# 2          thermal    121.624579
# 3            hydro      3.952421
# 4            hydro      4.040853
# ...            ...           ...
# 9995          wind     45.010305
# 9996         hydro      5.568225
# 9997       thermal  92352.824934
# 9998         hydro      4.729427
# 9999         hydro      3.104751
#
# [10000 rows x 8 columns]

# %%
df = generate_dataset(10000, profiles, energy_dist, emission_df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   company_id     10000 non-null  object
#  1   date           10000 non-null  datetime64[ns]
#  2   state          10000 non-null  object
#  3   usage_type     10000 non-null  object
#  4   fuel_type      10000 non-null  object
#  5   energy_kwh     10000 non-null  float64
#  6   energy_source  10000 non-null  object
#  7   co2_emission   10000 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 625.1+ KB

# %% [markdown]
# Extraindo a probabilidade do tramanho do negocio small, medium e large. Para criar dataset mais realista !

# %%
df_epe = pd.read_csv('/content/carbon-footprint-analysis/data/raw/EPE - Dados_abertos_Consumo_Mensal.CSV',
                    encoding='latin-1',
                    sep=';',
                    decimal=',')

# %%
df_epe['Consumo'] = (
    df_epe['Consumo']
    .str.replace('.', '', regex=False)
    .str.replace(',', '.', regex=False)
    .astype(float)
)

# %%
df_epe['DataExcel'] = pd.to_datetime(df_epe['DataExcel'], dayfirst=True)

# %%
df_epe['year'] = df_epe['DataExcel'].dt.year
df_epe['month'] = df_epe['DataExcel'].dt.month

# %%
df_2025 = df_epe[df_epe['year'] == 2025].copy()

# %%
df_2025
# Out:
#           Data  DataExcel  UF Regiao            Sistema       Classe  \
# 0     20251201 2025-12-01  AC  Norte  SISTEMAS ISOLADOS    Comercial
# 1     20251201 2025-12-01  AC  Norte  SISTEMAS ISOLADOS   Industrial
# 2     20251201 2025-12-01  AC  Norte  SISTEMAS ISOLADOS       Outros
# 3     20251201 2025-12-01  AC  Norte  SISTEMAS ISOLADOS  Residencial
# 4     20251201 2025-12-01  AC  Norte  SISTEMAS ISOLADOS        Rural
# ...        ...        ...  ..    ...                ...          ...
# 3323  20250101 2025-01-01  TO  Norte  NORTE INTERLIGADO       Outros
# 3324  20250101 2025-01-01  TO  Norte  NORTE INTERLIGADO       Outros
# 3325  20250101 2025-01-01  TO  Norte  NORTE INTERLIGADO  Residencial
# 3326  20250101 2025-01-01  TO  Norte  NORTE INTERLIGADO        Rural
# 3327  20250101 2025-01-01  TO  Norte  NORTE INTERLIGADO        Rural
#
#      TipoConsumidor   Consumo Consumidores  DataVersao  year  month
# 0            Cativo     175.7          478  23/02/2026  2025     12
# 1            Cativo       7.0            4  23/02/2026  2025     12
# 2            Cativo     495.1          382  23/02/2026  2025     12
# 3            Cativo    1266.8        8.862  23/02/2026  2025     12
# 4            Cativo    1181.1          125  23/02/2026  2025     12
# ...             ...       ...          ...         ...   ...    ...
# 3323         Cativo   23253.4       10.272  23/02/2026  2025      1
# 3324          Livre    4551.3           92  23/02/2026  2025      1
# 3325         Cativo  112036.0      596.482  23/02/2026  2025      1
# 3326         Cativo   15481.4       41.242  23/02/2026  2025      1
# 3327          Livre    1705.2           24  23/02/2026  2025      1
#
# [3328 rows x 12 columns]

# %%
df_2025['DataExcel'].unique()
# Out:
# <DatetimeArray>
# ['2025-12-01 00:00:00', '2025-11-01 00:00:00', '2025-10-01 00:00:00',
#  '2025-09-01 00:00:00', '2025-08-01 00:00:00', '2025-07-01 00:00:00',
#  '2025-06-01 00:00:00', '2025-05-01 00:00:00', '2025-04-01 00:00:00',
#  '2025-03-01 00:00:00', '2025-02-01 00:00:00', '2025-01-01 00:00:00']
# Length: 12, dtype: datetime64[ns]

# %%
df_2025['year'].unique()
# Out:
# array([2025], dtype=int32)

# %%
df_epe = df_2025.copy()

# %%
def classify_company_size(row):

    usage = row['Classe']
    energy = row['Consumo']

    if usage == 'Industrial':
        if energy < 20000:
            return 'small'
        elif energy < 100000:
            return 'medium'
        else:
            return 'large'

    if usage == 'Comercial':
        if energy < 5000:
            return 'small'
        elif energy < 30000:
            return 'medium'
        else:
            return 'large'

    if usage == 'Residencial':
        return 'small'

    if usage == 'Rural':
        if energy < 10000:
            return 'small'
        elif energy < 50000:
            return 'medium'
        else:
            return 'large'

    if usage == 'Outros':
        if energy < 10000:
            return 'small'
        elif energy < 50000:
            return 'medium'
        else:
            return 'large'

# %%
df_epe['company_size'] = df_epe.apply(classify_company_size, axis=1)

# %%
df_epe['company_size'].value_counts()
# Out:
# company_size
# small     1408
# large     1255
# medium     665
# Name: count, dtype: int64

# %%
size_dist = (
    df_epe
    .groupby('Classe')['company_size']
    .value_counts(normalize=True)
    .reset_index(name='probability')
)

# %%
size_dist
# Out:
#          Classe company_size  probability
# 0     Comercial        large     0.736990
# 1     Comercial       medium     0.174402
# 2     Comercial        small     0.088608
# 3    Industrial        small     0.459198
# 4    Industrial        large     0.343015
# 5    Industrial       medium     0.197787
# 6        Outros        large     0.438028
# 7        Outros       medium     0.339437
# 8        Outros        small     0.222535
# 9   Residencial        small     1.000000
# 10        Rural        small     0.525937
# 11        Rural        large     0.247839
# 12        Rural       medium     0.226225

# %%
size_dist.to_csv(
    'v2_company_size_distribution_by_usage.csv',
    index=False
)

# %% [markdown]
# calculando a variancia por mes, meses podem impactar no consumo de energia !

# %%
df_epe = pd.read_csv('/content/carbon-footprint-analysis/data/raw/EPE - Dados_abertos_Consumo_Mensal.CSV',
                    encoding='latin-1',
                    sep=';',
                    decimal=',')

# %%
df_epe['Consumo'] = (
    df_epe['Consumo']
    .str.replace('.', '', regex=False)
    .str.replace(',', '.', regex=False)
    .astype(float)
)

# %%
df_epe['DataExcel'] = pd.to_datetime(df_epe['DataExcel'], dayfirst=True)

# %%
df_epe['year'] = df_epe['DataExcel'].dt.year
df_epe['month'] = df_epe['DataExcel'].dt.month

# %%
df_2025 = df_epe[df_epe['year'] == 2025].copy()

# %%
df_2025
# Out:
#           Data  DataExcel  UF Regiao            Sistema       Classe  \
# 0     20251201 2025-12-01  AC  Norte  SISTEMAS ISOLADOS    Comercial
# 1     20251201 2025-12-01  AC  Norte  SISTEMAS ISOLADOS   Industrial
# 2     20251201 2025-12-01  AC  Norte  SISTEMAS ISOLADOS       Outros
# 3     20251201 2025-12-01  AC  Norte  SISTEMAS ISOLADOS  Residencial
# 4     20251201 2025-12-01  AC  Norte  SISTEMAS ISOLADOS        Rural
# ...        ...        ...  ..    ...                ...          ...
# 3323  20250101 2025-01-01  TO  Norte  NORTE INTERLIGADO       Outros
# 3324  20250101 2025-01-01  TO  Norte  NORTE INTERLIGADO       Outros
# 3325  20250101 2025-01-01  TO  Norte  NORTE INTERLIGADO  Residencial
# 3326  20250101 2025-01-01  TO  Norte  NORTE INTERLIGADO        Rural
# 3327  20250101 2025-01-01  TO  Norte  NORTE INTERLIGADO        Rural
#
#      TipoConsumidor   Consumo Consumidores  DataVersao  year  month
# 0            Cativo     175.7          478  23/02/2026  2025     12
# 1            Cativo       7.0            4  23/02/2026  2025     12
# 2            Cativo     495.1          382  23/02/2026  2025     12
# 3            Cativo    1266.8        8.862  23/02/2026  2025     12
# 4            Cativo    1181.1          125  23/02/2026  2025     12
# ...             ...       ...          ...         ...   ...    ...
# 3323         Cativo   23253.4       10.272  23/02/2026  2025      1
# 3324          Livre    4551.3           92  23/02/2026  2025      1
# 3325         Cativo  112036.0      596.482  23/02/2026  2025      1
# 3326         Cativo   15481.4       41.242  23/02/2026  2025      1
# 3327          Livre    1705.2           24  23/02/2026  2025      1
#
# [3328 rows x 12 columns]

# %%
df_epe = df_2025.copy()

# %%
df_epe['month'] = df_epe['DataExcel'].dt.month

# %%
monthly_stats = (
    df_epe
    .groupby(['UF','Classe','month'])['Consumo']
    .agg(['mean','var'])
    .reset_index()
)

# %%
annual_mean = (
    df_epe
    .groupby(['UF','Classe'])['Consumo']
    .mean()
    .reset_index()
    .rename(columns={'Consumo':'annual_mean'})
)

# %%
monthly_stats = monthly_stats.merge(
    annual_mean,
    on=['UF','Classe']
)

# %%
monthly_stats['seasonal_factor'] = (
    monthly_stats['mean'] /
    monthly_stats['annual_mean']
)

# %%
monthly_stats
# Out:
#       UF     Classe  month          mean           var   annual_mean  \
# 0     AC  Comercial      1   7714.300000  6.714684e+07   7870.066667
# 1     AC  Comercial      2   7516.866667  6.767137e+07   7870.066667
# 2     AC  Comercial      3   7665.733333  6.396008e+07   7870.066667
# 3     AC  Comercial      4   7678.133333  6.649973e+07   7870.066667
# 4     AC  Comercial      5   8107.200000  7.436601e+07   7870.066667
# ...   ..        ...    ...           ...           ...           ...
# 1615  TO      Rural      8  13812.350000  2.121120e+08  10657.095833
# 1616  TO      Rural      9  12308.500000  1.619640e+08  10657.095833
# 1617  TO      Rural     10  10554.700000  1.126921e+08  10657.095833
# 1618  TO      Rural     11  10315.150000  1.275795e+08  10657.095833
# 1619  TO      Rural     12   8838.850000  9.363277e+07  10657.095833
#
#       seasonal_factor
# 0            0.980208
# 1            0.955121
# 2            0.974037
# 3            0.975612
# 4            1.030131
# ...               ...
# 1615         1.296071
# 1616         1.154958
# 1617         0.990392
# 1618         0.967914
# 1619         0.829386
#
# [1620 rows x 7 columns]

# %%
monthly_stats = monthly_stats[[
    'UF',
    'Classe',
    'month',
    'seasonal_factor',
    'var'
]]

monthly_stats.to_csv(
    'v2_seasonality_state_class_month.csv',
    index=False
)

# %% [markdown]
# Gerando df completo

# %%
# !ls
# Out:
#  carbon-footprint-analysis	    sample_data
#  consumo_medio_categoria_2025.csv   usage_distribution_by_state.csv
#  df_gerado_teste.csv		    v2_company_size_distribution_by_usage.csv
# 'energy _source_distribution.csv'   v2_consumption_profiles.csv
#  media_consumo_indutria_2025.csv    v2_seasonality_state_class_month.csv

# %%
from pathlib import Path

ROOT = Path().resolve().parent

# %%
# !pwd
# Out:
# /content

# %%
# !git pull
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# import csvs

# %%
import pandas as pd
import numpy as np

profiles = pd.read_csv('/content/carbon-footprint-analysis/data/external/v2_consumption_profiles.csv')

energy_dist = pd.read_csv('/content/carbon-footprint-analysis/data/external/v2_energy _source_distribution.csv')

emission_df = pd.read_csv('/content/carbon-footprint-analysis/data/external/v2_energy_source_emission_factors.csv')

usage_distribution_by_state = pd.read_csv(
    '/content/carbon-footprint-analysis/data/external/v2_usage_distribution_by_state.csv',
    index_col=0
)

company_size_dist = pd.read_csv(
    '/content/carbon-footprint-analysis/data/external/v2_company_size_distribution_by_usage.csv'
)

seasonality = pd.read_csv(
    '/content/carbon-footprint-analysis/data/external/v2_seasonality_state_class_month.csv'
)

# %% [markdown]
# Sanity para integrar todos as tabelas estava dando MUITOS erros !

# %%
profiles['usage_type'] = profiles['usage_type'].str.lower()

usage_distribution_by_state.columns = usage_distribution_by_state.columns.str.lower()

company_size_dist['Classe'] = company_size_dist['Classe'].str.lower()

seasonality['Classe'] = seasonality['Classe'].str.lower()

# %%
print('profiles: '+profiles.columns,'\n')
print('energy_dist: '+energy_dist.columns,'\n')
print('emission_df: '+emission_df.columns,'\n')
print('usage_distribution_by_state: '+usage_distribution_by_state.columns,'\n')
print('company_size_dist: '+company_size_dist.columns,'\n')
print('seasonality: '+seasonality.columns,'\n')
# Out:
# Index(['profiles: usage_type', 'profiles: fuel_type',
#        'profiles: distribution_type', 'profiles: param_1', 'profiles: param_2',
#        'profiles: param_1_name', 'profiles: param_2_name', 'profiles: unit',
#        'profiles: is_energy_based'],
#       dtype='object')
#
# Index(['energy_dist: Unnamed: 0', 'energy_dist: energy_source',
#        'energy_dist: probability'],
#       dtype='object')
#
# Index(['emission_df: energy_source', 'emission_df: emission_factor'], dtype='object')
#
# Index(['usage_distribution_by_state: comercial',
#        'usage_distribution_by_state: industrial',
#        'usage_distribution_by_state: outros',
#        'usage_distribution_by_state: residencial',
#        'usage_distribution_by_state: rural'],
#       dtype='object')
#
# Index(['company_size_dist: Classe', 'company_size_dist: company_size',
#        'company_size_dist: probability'],
#       dtype='object')
#
# Index(['seasonality: UF', 'seasonality: Classe', 'seasonality: month',
#        'seasonality: seasonal_factor', 'seasonality: var'],
#       dtype='object')

# %%
def show_uniques(df, name):
    print(f"\n{name}")
    for col in df.select_dtypes(include='object').columns:
        print(col, "->", df[col].unique())

# %%
show_uniques(profiles, "profiles")
show_uniques(company_size_dist, "company_size_dist")
show_uniques(usage_distribution_by_state, "usage_distribution")
show_uniques(seasonality, "seasonality")
# Out:
# profiles
# usage_type -> ['industrial' 'residencial' 'comercial' 'outros' 'rural']
# fuel_type -> ['eletrico']
# distribution_type -> ['lognormal']
# param_1_name -> ['mu']
# param_2_name -> ['sigma']
# unit -> ['kWh']
#
# company_size_dist
# Classe -> ['comercial' 'industrial' 'outros' 'residencial' 'rural']
# company_size -> ['large' 'medium' 'small']
#
# usage_distribution
#
# seasonality
# UF -> ['AC' 'AL' 'AM' 'AP' 'BA' 'CE' 'DF' 'ES' 'GO' 'MA' 'MG' 'MS' 'MT' 'PA'
#  'PB' 'PE' 'PI' 'PR' 'RJ' 'RN' 'RO' 'RR' 'RS' 'SC' 'SE' 'SP' 'TO']
# Classe -> ['comercial' 'industrial' 'outros' 'residencial' 'rural']

# %%
print(set(profiles['usage_type']))
print(set(company_size_dist['Classe']))
print(set(usage_distribution_by_state.columns))
print(set(seasonality['Classe']))
# Out:
# {'residencial', 'outros', 'comercial', 'industrial', 'rural'}
# {'residencial', 'outros', 'comercial', 'industrial', 'rural'}
# {'residencial', 'outros', 'comercial', 'industrial', 'rural'}
# {'residencial', 'outros', 'comercial', 'industrial', 'rural'}

# %%
print("usage_types possíveis:", usage_distribution_by_state.columns.tolist())
print("classes em company_size:", company_size_dist['Classe'].unique())
# Out:
# usage_types possíveis: ['comercial', 'industrial', 'outros', 'residencial', 'rural']
# classes em company_size: ['comercial' 'industrial' 'outros' 'residencial' 'rural']

# %%
for u in usage_distribution_by_state.columns:
    subset = company_size_dist[company_size_dist['Classe'] == u]
    print(u, "->", len(subset))
# Out:
# comercial -> 3
# industrial -> 3
# outros -> 3
# residencial -> 1
# rural -> 3

# %%
print(energy_dist['probability'].sum())
# Out:
# 0.9999999999999998

# %%
print(company_size_dist.groupby('Classe')['probability'].sum())
# Out:
# Classe
# comercial      1.0
# industrial     1.0
# outros         1.0
# residencial    1.0
# rural          1.0
# Name: probability, dtype: float64

# %% [markdown]
# função geração consumo

# %%
def generate_consumption(profile_row):

    if profile_row['distribution_type'] == 'lognormal':

        mu = profile_row['param_1']
        sigma = profile_row['param_2']

        value = np.random.lognormal(mu, sigma)

        max_value = 10 * np.exp(mu)
        value = min(value, max_value)

        return value

    else:
        raise ValueError("Distribuição não suportada")

# %% [markdown]
# fonte energetica

# %%
def sample_energy_source(dist_df):

    return dist_df.sample(
        1,
        weights=dist_df['probability']
    ).iloc[0]['energy_source']

# %% [markdown]
# calcular emissão

# %%
def calculate_emission(energy_kwh, energy_source, emission_df):

    row = emission_df.loc[
        emission_df['energy_source'] == energy_source
    ]

    factor = row['emission_factor'].values[0]

    return energy_kwh * factor

# %% [markdown]
# amostra tamanho da empresa

# %%
def sample_company_size(usage_type):

    subset = company_size_dist[company_size_dist['Classe'] == usage_type]

    if len(subset) == 1:
        return subset['company_size'].iloc[0]

    return np.random.choice(
        subset['company_size'],
        p=subset['probability']
    )

# %% [markdown]
# aplicar sazionalidade

# %%
def apply_seasonality(consumption, state, usage_class, month):

    subset = seasonality[
        (seasonality['UF'] == state) &
        (seasonality['Classe'] == usage_class.capitalize()) &
        (seasonality['month'] == month)
    ]

    if subset.empty:
        return consumption

    factor = subset['seasonal_factor'].values[0]

    return consumption * factor

# %% [markdown]
# gerar evento (juntar tudo)

# %%
def generate_event(profiles):

    # estado
    state = np.random.choice(states, p=state_weights)

    # mês
    month = np.random.randint(1, 13)

    # setor baseado no estado
    usage_probs_state = usage_distribution_by_state.loc[state].values
    usage_probs_state = usage_probs_state / usage_probs_state.sum()

    usage_types = usage_distribution_by_state.columns

    usage_type = np.random.choice(
        usage_types,
        p=usage_probs_state
    )

    # profile do setor
    profiles_subset = profiles[profiles['usage_type'] == usage_type]

    # proteção contra subset vazio
    if profiles_subset.empty:
        raise ValueError(f"Nenhum profile encontrado para {usage_type}")

    row = profiles_subset.sample(1).iloc[0]

    # consumo base
    consumption = generate_consumption(row)

    # sazonalidade
    consumption = apply_seasonality(
        consumption,
        state,
        usage_type,
        month
    )

    # tamanho da empresa
    company_size = sample_company_size(usage_type)

    # fonte energética
    energy_source = sample_energy_source(energy_dist)

    # emissão
    co2 = calculate_emission(consumption, energy_source, emission_df)

    # data baseada no mês sorteado
    date = (
        pd.Timestamp('2025-01-01')
        + pd.DateOffset(months=month-1)
        + pd.to_timedelta(np.random.randint(0,28), unit='D')
    )

    return {

        'company_id': f"C{np.random.randint(100000,999999)}",

        'date': date,

        'state': state,

        'usage_type': usage_type,

        'company_size': company_size,

        'fuel_type': row['fuel_type'],

        'energy_kwh': consumption,

        'energy_source': energy_source,

        'co2_emission': co2
    }

# %% [markdown]
# gerar dataset

# %%
def generate_dataset(n):

    data = []

    for _ in range(n):
        data.append(generate_event(profiles))

    return pd.DataFrame(data)

# %% [markdown]
# Montar dataset com tudo

# %%
df = generate_dataset(100000)

df.head()
# Out:
#   company_id       date state   usage_type company_size fuel_type  \
# 0    C951085 2025-05-06    PR   industrial       medium  eletrico
# 1    C647800 2025-01-07    SP        rural        large  eletrico
# 2    C621890 2025-04-07    MT       outros       medium  eletrico
# 3    C408209 2025-01-19    PE  residencial        small  eletrico
# 4    C665550 2025-04-06    RS   industrial       medium  eletrico
#
#      energy_kwh energy_source  co2_emission
# 0  38541.683212         hydro    770.833664
# 1    649.198286         hydro     12.983966
# 2   3108.509999         hydro     62.170200
# 3    158.188545         hydro      3.163771
# 4  26015.691545       thermal  15609.414927
